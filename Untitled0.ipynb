# %% [markdown]
# <a href="https://colab.research.google.com/github/alaajomah/ML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(12.0,9.0)
data=pd.read_csv('students.csv')
x=data.iloc[:,0]
y=data.iloc[:,1]
plt.scatter(x,y)
plt.show()

# %%
#building the model
m=0
c=0

l=0.0001          #the learning rate
epochs=1000       # the number of iteration to perform gradient descent
n=float(len(x))   #number of element in x

#performing gradient descent 
for i in range(epochs):
  y_pred=m*x+c     #the current predicted value of y
  d_m=(-2/n)*sum(x*(y-y_pred))      #derivative wrt m
  d_c=(-2/n)*sum(y-y_pred)          #derivative wrt c
  m=m-l*d_m      #update m
  c=c-l*d_c      #update c
  
print(m,c)
# Out:
# 1.0309871950011718 0.18510267892925542

# %%
#making prediction
y_pred=m*x+c

plt.scatter(x,y)
plt.plot([min(x),max(x)],[min(y_pred),max(y_pred)],color='red')  #predicted

# %%
from google.colab import drive
drive.mount('/content/drive')
